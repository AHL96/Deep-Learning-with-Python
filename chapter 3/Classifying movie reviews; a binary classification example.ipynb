# %%
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# 1

# %%
max([max(s) for s in train_data])
# Out:
# 9999

# %%
word_index = imdb.get_word_index()
reverse_word_index = dict(
    [(v,k) for (k,v) in word_index.items()])
decoded_review = ' '.join(
    [reverse_word_index.get(i-3, '?') for i in train_data[0]])

# %%
reverse_word_index
# Out:
# {1: u'the',
#  2: u'and',
#  3: u'a',
#  4: u'of',
#  5: u'to',
#  6: u'is',
#  7: u'br',
#  8: u'in',
#  9: u'it',
#  10: u'i',
#  11: u'this',
#  12: u'that',
#  13: u'was',
#  14: u'as',
#  15: u'for',
#  16: u'with',
#  17: u'movie',
#  18: u'but',
#  19: u'film',
#  20: u'on',
#  21: u'not',
#  22: u'you',
#  23: u'are',
#  24: u'his',
#  25: u'have',
#  26: u'he',
#  27: u'be',
#  28: u'one',
#  29: u'all',
#  30: u'at',
#  31: u'by',
#  32: u'an',
#  33: u'they',
#  34: u'who',
#  35: u'so',
#  36: u'from',
#  37: u'like',
#  38: u'her',
#  39: u'or',
#  40: u'just',
#  41: u'about',
#  42: u"it's",
#  43: u'out',
#  44: u'has',
#  45: u'if',
#  46: u'some',
#  47: u'there',
#  48: u'what',
#  49: u'good',
#  50: u'more',
#  51: u'when',
#  52: u'very',
#  53: u'up',
#  54: u'no',
#  55: u'time',
#  56: u'she',
#  57: u'even',
#  58: u'my',
#  59: u'would',
#  60: u'which',
#  61: u'only',
#  62: u'story',
#  63: u'really',
#  64: u'see',
#  65: u'their',
#  66: u'had',
#  67: u'can',
#  68: u'were',
#  69: u'me',
#  70: u'well',
#  71: u'than',
#  72: u'we',
#  73: u'much',
#  74: u'been',
#  75: u'bad',
#  76: u'get',
#  77: u'will',
#  78: u'do',
#  79: u'also',
#  80: u'into',
#  81: u'people',
#  82: u'other',
#  83: u'first',
#  84: u'great',
#  85: u'because',
#  86: u'how',
#  87: u'him',
#  88: u'most',
#  89: u"don't",
#  90: u'made',
#  91: u'its',
#  92: u'then',
#  93: u'way',
#  94: u'make',
#  95: u'them',
#  96: u'too',
#  97: u'could',
#  98: u'any',
#  99: u'movies',
#  100: u'after',
#  101: u'think',
#  102: u'characters',
#  103: u'watch',
#  104: u'two',
#  105: u'films',
#  106: u'character',
#  107: u'seen',
#  108: u'many',
#  109: u'being',
#  110: u'life',
#  111: u'plot',
#  112: u'never',
#  113: u'acting',
#  114: u'little',
#  115: u'best',
#  116: u'love',
#  117: u'over',
#  118: u'where',
#  119: u'did',
#  120: u'show',
#  121: u'know',
#  122: u'off',
#  123: u'ever',
#  124: u'does',
#  125: u'better',
#  126: u'your',
#  127: u'end',
#  128: u'still',
#  129: u'man',
#  130: u'here',
#  131: u'these',
#  132: u'say',
#  133: u'scene',
#  134: u'while',
#  135: u'why',
#  136: u'scenes',
#  137: u'go',
#  138: u'such',
#  139: u'something',
#  140: u'through',
#  141: u'should',
#  142: u'back',
#  143: u"i'm",
#  144: u'real',
#  145: u'those',
#  146: u'watching',
#  147: u'now',
#  148: u'though',
#  149: u"doesn't",
#  150: u'years',
#  151: u'old',
#  152: u'thing',
#  153: u'actors',
#  154: u'work',
#  155: u'10',
#  156: u'before',
#  157: u'another',
#  158: u"didn't",
#  159: u'new',
#  160: u'funny',
#  161: u'nothing',
#  162: u'actually',
#  163: u'makes',
#  164: u'director',
#  165: u'look',
#  166: u'find',
#  167: u'going',
#  168: u'few',
#  169: u'same',
#  170: u'part',
#  171: u'again',
#  172: u'every',
#  173: u'lot',
#  174: u'cast',
#  175: u'us',
#  176: u'quite',
#  177: u'down',
#  178: u'want',
#  179: u'world',
#  180: u'things',
#  181: u'pretty',
#  182: u'young',
#  183: u'seems',
#  184: u'around',
#  185: u'got',
#  186: u'horror',
#  187: u'however',
#  188: u"can't",
#  189: u'fact',
#  190: u'take',
#  191: u'big',
#  192: u'enough',
#  193: u'long',
#  194: u'thought',
#  195: u"that's",
#  196: u'both',
#  197: u'between',
#  198: u'series',
#  199: u'give',
#  200: u'may',
#  201: u'original',
#  202: u'own',
#  203: u'action',
#  204: u"i've",
#  205: u'right',
#  206: u'without',
#  207: u'always',
#  208: u'times',
#  209: u'comedy',
#  210: u'point',
#  211: u'gets',
#  212: u'must',
#  213: u'come',
#  214: u'role',
#  215: u"isn't",
#  216: u'saw',
#  217: u'almost',
#  218: u'interesting',
#  219: u'least',
#  220: u'family',
#  221: u'done',
#  222: u"there's",
#  223: u'whole',
#  224: u'bit',
#  225: u'music',
#  226: u'script',
#  227: u'far',
#  228: u'making',
#  229: u'guy',
#  230: u'anything',
#  231: u'minutes',
#  232: u'feel',
#  233: u'last',
#  234: u'since',
#  235: u'might',
#  236: u'performance',
#  237: u"he's",
#  238: u'2',
#  239: u'probably',
#  240: u'kind',
#  241: u'am',
#  242: u'away',
#  243: u'yet',
#  244: u'rather',
#  245: u'tv',
#  246: u'worst',
#  247: u'girl',
#  248: u'day',
#  249: u'sure',
#  250: u'fun',
#  251: u'hard',
#  252: u'woman',
#  253: u'played',
#  254: u'each',
#  255: u'found',
#  256: u'anyone',
#  257: u'having',
#  258: u'although',
#  259: u'especially',
#  260: u'our',
#  261: u'believe',
#  262: u'course',
#  263: u'comes',
#  264: u'looking',
#  265: u'screen',
#  266: u'trying',
#  267: u'set',
#  268: u'goes',
#  269: u'looks',
#  270: u'place',
#  271: u'book',
#  272: u'different',
#  273: u'put',
#  274: u'ending',
#  275: u'money',
#  276: u'maybe',
#  277: u'once',
#  278: u'sense',
#  279: u'reason',
#  280: u'true',
#  281: u'actor',
#  282: u'everything',
#  283: u"wasn't",
#  284: u'shows',
#  285: u'dvd',
#  286: u'three',
#  287: u'worth',
#  288: u'year',
#  289: u'job',
#  290: u'main',
#  291: u'someone',
#  292: u'together',
#  293: u'watched',
#  294: u'play',
#  295: u'american',
#  296: u'plays',
#  297: u'1',
#  298: u'said',
#  299: u'effects',
#  300: u'later',
#  301: u'takes',
#  302: u'instead',
#  303: u'seem',
#  304: u'beautiful',
#  305: u'john',
#  306: u'himself',
#  307: u'version',
#  308: u'audience',
#  309: u'high',
#  310: u'house',
#  311: u'night',
#  312: u'during',
#  313: u'everyone',
#  314: u'left',
#  315: u'special',
#  316: u'seeing',
#  317: u'half',
#  318: u'excellent',
#  319: u'wife',
#  320: u'star',
#  321: u'shot',
#  322: u'war',
#  323: u'idea',
#  324: u'nice',
#  325: u'black',
#  326: u'less',
#  327: u'mind',
#  328: u'simply',
#  329: u'read',
#  330: u'second',
#  331: u'else',
#  332: u"you're",
#  333: u'father',
#  334: u'fan',
#  335: u'poor',
#  336: u'help',
#  337: u'completely',
#  338: u'death',
#  339: u'3',
#  340: u'used',
#  341: u'home',
#  342: u'either',
#  343: u'short',
#  344: u'line',
#  345: u'given',
#  346: u'men',
#  347: u'top',
#  348: u'dead',
#  349: u'budget',
#  350: u'try',
#  351: u'performances',
#  352: u'wrong',
#  353: u'classic',
#  354: u'boring',
#  355: u'enjoy',
#  356: u'need',
#  357: u'rest',
#  358: u'use',
#  359: u'kids',
#  360: u'hollywood',
#  361: u'low',
#  362: u'production',
#  363: u'until',
#  364: u'along',
#  365: u'full',
#  366: u'friends',
#  367: u'camera',
#  368: u'truly',
#  369: u'women',
#  370: u'awful',
#  371: u'video',
#  372: u'next',
#  373: u'tell',
#  374: u'remember',
#  375: u'couple',
#  376: u'stupid',
#  377: u'start',
#  378: u'stars',
#  379: u'perhaps',
#  380: u'sex',
#  381: u'mean',
#  382: u'came',
#  383: u'recommend',
#  384: u'let',
#  385: u'moments',
#  386: u'wonderful',
#  387: u'episode',
#  388: u'understand',
#  389: u'small',
#  390: u'face',
#  391: u'terrible',
#  392: u'playing',
#  393: u'school',
#  394: u'getting',
#  395: u'written',
#  396: u'doing',
#  397: u'often',
#  398: u'keep',
#  399: u'early',
#  400: u'name',
#  401: u'perfect',
#  402: u'style',
#  403: u'human',
#  404: u'definitely',
#  405: u'gives',
#  406: u'others',
#  407: u'itself',
#  408: u'lines',
#  409: u'live',
#  410: u'become',
#  411: u'dialogue',
#  412: u'person',
#  413: u'lost',
#  414: u'finally',
#  415: u'piece',
#  416: u'head',
#  417: u'case',
#  418: u'felt',
#  419: u'yes',
#  420: u'liked',
#  421: u'supposed',
#  422: u'title',
#  423: u"couldn't",
#  424: u'absolutely',
#  425: u'white',
#  426: u'against',
#  427: u'boy',
#  428: u'picture',
#  429: u'sort',
#  430: u'worse',
#  431: u'certainly',
#  432: u'went',
#  433: u'entire',
#  434: u'waste',
#  435: u'cinema',
#  436: u'problem',
#  437: u'hope',
#  438: u'entertaining',
#  439: u"she's",
#  440: u'mr',
#  441: u'overall',
#  442: u'evil',
#  443: u'called',
#  444: u'loved',
#  445: u'based',
#  446: u'oh',
#  447: u'several',
#  448: u'fans',
#  449: u'mother',
#  450: u'drama',
#  451: u'beginning',
#  452: u'killer',
#  453: u'lives',
#  454: u'5',
#  455: u'direction',
#  456: u'care',
#  457: u'already',
#  458: u'becomes',
#  459: u'laugh',
#  460: u'example',
#  461: u'friend',
#  462: u'dark',
#  463: u'despite',
#  464: u'under',
#  465: u'seemed',
#  466: u'throughout',
#  467: u'4',
#  468: u'turn',
#  469: u'unfortunately',
#  470: u'wanted',
#  471: u"i'd",
#  472: u'\x96',
#  473: u'children',
#  474: u'final',
#  475: u'fine',
#  476: u'history',
#  477: u'amazing',
#  478: u'sound',
#  479: u'guess',
#  480: u'heart',
#  481: u'totally',
#  482: u'lead',
#  483: u'humor',
#  484: u'writing',
#  485: u'michael',
#  486: u'quality',
#  487: u"you'll",
#  488: u'close',
#  489: u'son',
#  490: u'guys',
#  491: u'wants',
#  492: u'works',
#  493: u'behind',
#  494: u'tries',
#  495: u'art',
#  496: u'side',
#  497: u'game',
#  498: u'past',
#  499: u'able',
#  500: u'b',
#  501: u'days',
#  502: u'turns',
#  503: u'child',
#  504: u"they're",
#  505: u'hand',
#  506: u'flick',
#  507: u'enjoyed',
#  508: u'act',
#  509: u'genre',
#  510: u'town',
#  511: u'favorite',
#  512: u'soon',
#  513: u'kill',
#  514: u'starts',
#  515: u'sometimes',
#  516: u'car',
#  517: u'gave',
#  518: u'run',
#  519: u'late',
#  520: u'eyes',
#  521: u'actress',
#  522: u'etc',
#  523: u'directed',
#  524: u'horrible',
#  525: u"won't",
#  526: u'viewer',
#  527: u'brilliant',
#  528: u'parts',
#  529: u'self',
#  530: u'themselves',
#  531: u'hour',
#  532: u'expect',
#  533: u'thinking',
#  534: u'stories',
#  535: u'stuff',
#  536: u'girls',
#  537: u'obviously',
#  538: u'blood',
#  539: u'decent',
#  540: u'city',
#  541: u'voice',
#  542: u'highly',
#  543: u'myself',
#  544: u'feeling',
#  545: u'fight',
#  546: u'except',
#  547: u'slow',
#  548: u'matter',
#  549: u'type',
#  550: u'anyway',
#  551: u'kid',
#  552: u'roles',
#  553: u'killed',
#  554: u'heard',
#  555: u'god',
#  556: u'age',
#  557: u'says',
#  558: u'moment',
#  559: u'took',
#  560: u'leave',
#  561: u'writer',
#  562: u'strong',
#  563: u'cannot',
#  564: u'violence',
#  565: u'police',
#  566: u'hit',
#  567: u'stop',
#  568: u'happens',
#  569: u'particularly',
#  570: u'known',
#  571: u'involved',
#  572: u'happened',
#  573: u'extremely',
#  574: u'daughter',
#  575: u'obvious',
#  576: u'told',
#  577: u'chance',
#  578: u'living',
#  579: u'coming',
#  580: u'lack',
#  581: u'alone',
#  582: u'experience',
#  583: u"wouldn't",
#  584: u'including',
#  585: u'murder',
#  586: u'attempt',
#  587: u's',
#  588: u'please',
#  589: u'james',
#  590: u'happen',
#  591: u'wonder',
#  592: u'crap',
#  593: u'ago',
#  594: u'brother',
#  595: u"film's",
#  596: u'gore',
#  597: u'none',
#  598: u'complete',
#  599: u'interest',
#  600: u'score',
#  601: u'group',
#  602: u'cut',
#  603: u'simple',
#  604: u'save',
#  605: u'ok',
#  606: u'hell',
#  607: u'looked',
#  608: u'career',
#  609: u'number',
#  610: u'song',
#  611: u'possible',
#  612: u'seriously',
#  613: u'annoying',
#  614: u'shown',
#  615: u'exactly',
#  616: u'sad',
#  617: u'running',
#  618: u'musical',
#  619: u'serious',
#  620: u'taken',
#  621: u'yourself',
#  622: u'whose',
#  623: u'released',
#  624: u'cinematography',
#  625: u'david',
#  626: u'scary',
#  627: u'ends',
#  628: u'english',
#  629: u'hero',
#  630: u'usually',
#  631: u'hours',
#  632: u'reality',
#  633: u'opening',
#  634: u"i'll",
#  635: u'across',
#  636: u'today',
#  637: u'jokes',
#  638: u'light',
#  639: u'hilarious',
#  640: u'somewhat',
#  641: u'usual',
#  642: u'started',
#  643: u'cool',
#  644: u'ridiculous',
#  645: u'body',
#  646: u'relationship',
#  647: u'view',
#  648: u'level',
#  649: u'opinion',
#  650: u'change',
#  651: u'happy',
#  652: u'middle',
#  653: u'taking',
#  654: u'wish',
#  655: u'husband',
#  656: u'finds',
#  657: u'saying',
#  658: u'order',
#  659: u'talking',
#  660: u'ones',
#  661: u'documentary',
#  662: u'shots',
#  663: u'huge',
#  664: u'novel',
#  665: u'female',
#  666: u'mostly',
#  667: u'robert',
#  668: u'power',
#  669: u'episodes',
#  670: u'room',
#  671: u'important',
#  672: u'rating',
#  673: u'talent',
#  674: u'five',
#  675: u'major',
#  676: u'turned',
#  677: u'strange',
#  678: u'word',
#  679: u'modern',
#  680: u'call',
#  681: u'apparently',
#  682: u'disappointed',
#  683: u'single',
#  684: u'events',
#  685: u'due',
#  686: u'four',
#  687: u'songs',
#  688: u'basically',
#  689: u'attention',
#  690: u'7',
#  691: u'knows',
#  692: u'clearly',
#  693: u'supporting',
#  694: u'knew',
#  695: u'british',
#  696: u'television',
#  697: u'comic',
#  698: u'non',
#  699: u'fast',
#  700: u'earth',
#  701: u'country',
#  702: u'future',
#  703: u'cheap',
#  704: u'class',
#  705: u'thriller',
#  706: u'8',
#  707: u'silly',
#  708: u'king',
#  709: u'problems',
#  710: u"aren't",
#  711: u'easily',
#  712: u'words',
#  713: u'tells',
#  714: u'miss',
#  715: u'jack',
#  716: u'local',
#  717: u'sequence',
#  718: u'bring',
#  719: u'entertainment',
#  720: u'paul',
#  721: u'beyond',
#  722: u'upon',
#  723: u'whether',
#  724: u'predictable',
#  725: u'moving',
#  726: u'similar',
#  727: u'straight',
#  728: u'romantic',
#  729: u'sets',
#  730: u'review',
#  731: u'falls',
#  732: u'oscar',
#  733: u'mystery',
#  734: u'enjoyable',
#  735: u'needs',
#  736: u'appears',
#  737: u'talk',
#  738: u'rock',
#  739: u'george',
#  740: u'giving',
#  741: u'eye',
#  742: u'richard',
#  743: u'within',
#  744: u'ten',
#  745: u'animation',
#  746: u'message',
#  747: u'theater',
#  748: u'near',
#  749: u'above',
#  750: u'dull',
#  751: u'nearly',
#  752: u'sequel',
#  753: u'theme',
#  754: u'points',
#  755: u"'",
#  756: u'stand',
#  757: u'mention',
#  758: u'lady',
#  759: u'bunch',
#  760: u'add',
#  761: u'feels',
#  762: u'herself',
#  763: u'release',
#  764: u'red',
#  765: u'team',
#  766: u'storyline',
#  767: u'surprised',
#  768: u'ways',
#  769: u'using',
#  770: u'named',
#  771: u"haven't",
#  772: u'lots',
#  773: u'easy',
#  774: u'fantastic',
#  775: u'begins',
#  776: u'actual',
#  777: u'working',
#  778: u'effort',
#  779: u'york',
#  780: u'die',
#  781: u'hate',
#  782: u'french',
#  783: u'minute',
#  784: u'tale',
#  785: u'clear',
#  786: u'stay',
#  787: u'9',
#  788: u'elements',
#  789: u'feature',
#  790: u'among',
#  791: u'follow',
#  792: u'comments',
#  793: u're',
#  794: u'viewers',
#  795: u'avoid',
#  796: u'sister',
#  797: u'showing',
#  798: u'typical',
#  799: u'editing',
#  800: u"what's",
#  801: u'famous',
#  802: u'tried',
#  803: u'sorry',
#  804: u'dialog',
#  805: u'check',
#  806: u'fall',
#  807: u'period',
#  808: u'season',
#  809: u'form',
#  810: u'certain',
#  811: u'filmed',
#  812: u'weak',
#  813: u'soundtrack',
#  814: u'means',
#  815: u'buy',
#  816: u'material',
#  817: u'somehow',
#  818: u'realistic',
#  819: u'figure',
#  820: u'crime',
#  821: u'doubt',
#  822: u'gone',
#  823: u'peter',
#  824: u'tom',
#  825: u'kept',
#  826: u'viewing',
#  827: u't',
#  828: u'general',
#  829: u'leads',
#  830: u'greatest',
#  831: u'space',
#  832: u'lame',
#  833: u'suspense',
#  834: u'dance',
#  835: u'imagine',
#  836: u'brought',
#  837: u'third',
#  838: u'atmosphere',
#  839: u'hear',
#  840: u'particular',
#  841: u'sequences',
#  842: u'whatever',
#  843: u'parents',
#  844: u'move',
#  845: u'lee',
#  846: u'indeed',
#  847: u'learn',
#  848: u'rent',
#  849: u'de',
#  850: u'eventually',
#  851: u'note',
#  852: u'deal',
#  853: u'average',
#  854: u'reviews',
#  855: u'wait',
#  856: u'forget',
#  857: u'japanese',
#  858: u'sexual',
#  859: u'poorly',
#  860: u'premise',
#  861: u'okay',
#  862: u'zombie',
#  863: u'surprise',
#  864: u'believable',
#  865: u'stage',
#  866: u'possibly',
#  867: u'sit',
#  868: u"who's",
#  869: u'decided',
#  870: u'expected',
#  871: u"you've",
#  872: u'subject',
#  873: u'nature',
#  874: u'became',
#  875: u'difficult',
#  876: u'free',
#  877: u'killing',
#  878: u'screenplay',
#  879: u'truth',
#  880: u'romance',
#  881: u'dr',
#  882: u'nor',
#  883: u'reading',
#  884: u'needed',
#  885: u'question',
#  886: u'leaves',
#  887: u'street',
#  888: u'20',
#  889: u'meets',
#  890: u'hot',
#  891: u'unless',
#  892: u'begin',
#  893: u'baby',
#  894: u'superb',
#  895: u'credits',
#  896: u'imdb',
#  897: u'otherwise',
#  898: u'write',
#  899: u'shame',
#  900: u"let's",
#  901: u'situation',
#  902: u'dramatic',
#  903: u'memorable',
#  904: u'directors',
#  905: u'earlier',
#  906: u'meet',
#  907: u'disney',
#  908: u'open',
#  909: u'dog',
#  910: u'badly',
#  911: u'joe',
#  912: u'male',
#  913: u'weird',
#  914: u'acted',
#  915: u'forced',
#  916: u'laughs',
#  917: u'sci',
#  918: u'emotional',
#  919: u'older',
#  920: u'realize',
#  921: u'fi',
#  922: u'dream',
#  923: u'society',
#  924: u'writers',
#  925: u'interested',
#  926: u'footage',
#  927: u'forward',
#  928: u'comment',
#  929: u'crazy',
#  930: u'deep',
#  931: u'sounds',
#  932: u'plus',
#  933: u'beauty',
#  934: u'whom',
#  935: u'america',
#  936: u'fantasy',
#  937: u'directing',
#  938: u'keeps',
#  939: u'ask',
#  940: u'development',
#  941: u'features',
#  942: u'air',
#  943: u'quickly',
#  944: u'mess',
#  945: u'creepy',
#  946: u'towards',
#  947: u'perfectly',
#  948: u'mark',
#  949: u'worked',
#  950: u'box',
#  951: u'cheesy',
#  952: u'unique',
#  953: u'setting',
#  954: u'hands',
#  955: u'plenty',
#  956: u'result',
#  957: u'previous',
#  958: u'brings',
#  959: u'effect',
#  960: u'e',
#  961: u'total',
#  962: u'personal',
#  963: u'incredibly',
#  964: u'rate',
#  965: u'fire',
#  966: u'monster',
#  967: u'business',
#  968: u'leading',
#  969: u'apart',
#  970: u'casting',
#  971: u'admit',
#  972: u'joke',
#  973: u'powerful',
#  974: u'appear',
#  975: u'background',
#  976: u'telling',
#  977: u'girlfriend',
#  978: u'meant',
#  979: u'christmas',
#  980: u'hardly',
#  981: u'present',
#  982: u'battle',
#  983: u'potential',
#  984: u'create',
#  985: u'bill',
#  986: u'break',
#  987: u'pay',
#  988: u'masterpiece',
#  989: u'gay',
#  990: u'political',
#  991: u'return',
#  992: u'dumb',
#  993: u'fails',
#  994: u'fighting',
#  995: u'various',
#  996: u'era',
#  997: u'portrayed',
#  998: u'co',
#  999: u'cop',
#  1000: u'secret',
#  ...}

# %%
decoded_review
# Out:
# u"? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
import numpy as np

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 3s 190us/step - loss: 0.5090 - acc: 0.7813 - val_loss: 0.3793 - val_acc: 0.8691
# Epoch 2/20
# 15000/15000 [==============================] - 2s 135us/step - loss: 0.3006 - acc: 0.9050 - val_loss: 0.3003 - val_acc: 0.8893
# Epoch 3/20
# 15000/15000 [==============================] - 2s 137us/step - loss: 0.2180 - acc: 0.9285 - val_loss: 0.3085 - val_acc: 0.8716
# Epoch 4/20
# 15000/15000 [==============================] - 2s 136us/step - loss: 0.1751 - acc: 0.9435 - val_loss: 0.2836 - val_acc: 0.8837
# Epoch 5/20
# 15000/15000 [==============================] - 2s 134us/step - loss: 0.1426 - acc: 0.9542 - val_loss: 0.2842 - val_acc: 0.8873
# Epoch 6/20
# 15000/15000 [==============================] - 2s 143us/step - loss: 0.1150 - acc: 0.9653 - val_loss: 0.3148 - val_acc: 0.8777
# Epoch 7/20
# 15000/15000 [==============================] - 3s 167us/step - loss: 0.0978 - acc: 0.9707 - val_loss: 0.3128 - val_acc: 0.8846
# Epoch 8/20
# 15000/15000 [==============================] - 3s 176us/step - loss: 0.0806 - acc: 0.9765 - val_loss: 0.3858 - val_acc: 0.8652
# Epoch 9/20
# 15000/15000 [==============================] - 2s 158us/step - loss: 0.0660 - acc: 0.9821 - val_loss: 0.3638 - val_acc: 0.8779
# Epoch 10/20
# 15000/15000 [==============================] - 2s 151us/step - loss: 0.0565 - acc: 0.9853 - val_loss: 0.3846 - val_acc: 0.8797
# Epoch 11/20
# 15000/15000 [==============================] - 2s 144us/step - loss: 0.0424 - acc: 0.9905 - val_loss: 0.4131 - val_acc: 0.8779
# Epoch 12/20
# 15000/15000 [==============================] - 2s 144us/step - loss: 0.0372 - acc: 0.9922 - val_loss: 0.4633 - val_acc: 0.8679
# Epoch 13/20
# 15000/15000 [==============================] - 2s 158us/step - loss: 0.0297 - acc: 0.9932 - val_loss: 0.4733 - val_acc: 0.8729
# Epoch 14/20
# 15000/15000 [==============================] - 2s 146us/step - loss: 0.0245 - acc: 0.9945 - val_loss: 0.5067 - val_acc: 0.8725
# Epoch 15/20
# 15000/15000 [==============================] - 2s 151us/step - loss: 0.0196 - acc: 0.9967 - val_loss: 0.5335 - val_acc: 0.8703
# Epoch 16/20
# 15000/15000 [==============================] - 2s 156us/step - loss: 0.0144 - acc: 0.9981 - val_loss: 0.5717 - val_acc: 0.8692
# Epoch 17/20
# 15000/15000 [==============================] - 3s 168us/step - loss: 0.0142 - acc: 0.9975 - val_loss: 0.6032 - val_acc: 0.8674
# Epoch 18/20
# 15000/15000 [==============================] - 2s 155us/step - loss: 0.0102 - acc: 0.9984 - val_loss: 0.6329 - val_acc: 0.8670
# Epoch 19/20
# 15000/15000 [==============================] - 2s 153us/step - loss: 0.0057 - acc: 0.9998 - val_loss: 0.7189 - val_acc: 0.8568
# Epoch 20/20
# 15000/15000 [==============================] - 2s 166us/step - loss: 0.0111 - acc: 0.9973 - val_loss: 0.6942 - val_acc: 0.8675

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

acc = history_dict['acc']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation lost')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validaiton acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
print results
# Out:
# Epoch 1/4
# 25000/25000 [==============================] - 3s 118us/step - loss: 0.4749 - acc: 0.8217
# Epoch 2/4
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.2659 - acc: 0.9097
# Epoch 3/4
# 25000/25000 [==============================] - 2s 98us/step - loss: 0.1983 - acc: 0.9298
# Epoch 4/4
# 25000/25000 [==============================] - 2s 98us/step - loss: 0.1678 - acc: 0.9402
# 25000/25000 [==============================] - 3s 101us/step
# [0.32455967262268065, 0.87308]

# %%
model.predict(x_test)
# Out:
# array([[0.14020061],
#        [0.9997023 ],
#        [0.28676784],
#        ...,
#        [0.07140668],
#        [0.04296872],
#        [0.47203013]], dtype=float32)
